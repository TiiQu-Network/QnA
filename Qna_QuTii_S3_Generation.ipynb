# %% [markdown]
# ### Libraries

# %%
import boto3
import pandas as pd
import os
import numpy as np
import nltk
from nltk import tokenize
import tempfile
import openai
import csv

# %% [markdown]
# ### Fetch file from S3 Bucket

# %%
# Define bucket object
s3 = boto3.client('s3')

# Change the file you want to download accordingly
with open('text_data.xlsx', 'wb') as f:
    s3.download_fileobj('tiiqu-openresearch', 'data-ingression/climate_risk_f1000.xlsx', f)

# %% [markdown]
# ### Convert text data to paragraphs

# %%
# Read in the excel file
text_data = pd.read_excel('text_data.xlsx')
text_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              169 non-null    object
#  1   DOI                172 non-null    object
#  2   Authors            169 non-null    object
#  3   Full_Text_URL      172 non-null    object
#  4   Full_Text_Content  169 non-null    object
# dtypes: object(5)
# memory usage: 6.8+ KB

# %%
text_data.sample(1)
# Out:
#                                                 Title  \
# 59  Green Rating for Integrated Habitat Assessment...
#
#                                 DOI  \
# 59  10.12688/f1000research.108826.1
#
#                                               Authors  \
# 59  [{'Priyanka', 'Kochhar'}, {'Namrata', 'Mahal'}...
#
#                                         Full_Text_URL  \
# 59  https://f1000research.com/extapi/article/xml?d...
#
#                                     Full_Text_Content
# 59  \n\n1. Introduction\nBuildings contribute to 3...

# %%
text_data[text_data.isnull().any(axis=1)]
# Out:
#     Title                              DOI Authors  \
# 56    NaN   10.12688/f1000research.70650.3     NaN
# 66    NaN  10.12688/f1000research.111073.1     NaN
# 154   NaN  10.12688/f1000research.124234.1     NaN
#
#                                          Full_Text_URL Full_Text_Content
# 56   https://f1000research.com/extapi/article/xml?d...               NaN
# 66   https://f1000research.com/extapi/article/xml?d...               NaN
# 154  https://f1000research.com/extapi/article/xml?d...               NaN

# %%
# Drop the nan value records since the url is invalid 
text_data = text_data.dropna().reset_index(drop=True)

# %%
# Create copy of text_data to mainpulate the data further
temp_df = text_data.copy()

# %%
# Function to tokenize the text and return the paragraphs
def get_paragraphs(text):
  
  # Tokenize the text
  result = tokenize.sent_tokenize(text)

  # Variables to store the tokenized strings and 
  str_paragraph = ''
  paragraphs = []

  for i in range(len(result)):

    sentence = result[i]
    len_para = len(tokenize.word_tokenize(str_paragraph))

    if len_para < 200:
      str_paragraph = str_paragraph + ' ' + sentence

    elif len_para >= 200 :
      paragraphs.append(str_paragraph)

      str_paragraph = ''
      str_paragraph = str_paragraph + ' ' + sentence

    elif i == len(result) - 1:
      paragraphs.append(str_paragraph)
    
  # Return the paragraphs
  return paragraphs

# %%
import openai

# Define the api key
openai.api_key = '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' #Make sure you use your own api key.

# Function to get the response from OpenAI's api
def get_response(text):

    response = openai.Completion.create(
      model="text-davinci-003",
      prompt="Generate 2 descriptive questions and answers per paragraph wise: "+text,
      temperature=0.9,
      max_tokens=200,   # Changing the value from 150 to 200
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )
    
    r = response.choices[0].text
    return r

# %%
# Function to get the Q&A pairs from the qna generated
def parse_qa_pairs(lines):
    pairs = []
    current_q = ''
    current_a = ''
    for line in lines:
        line = line.strip()
        if line.startswith('Q1') or line.startswith('Q2') or line.startswith('Question 1') or line.startswith('Question 2'):
 
            if current_q:
                pairs.append((current_q, current_a))
            current_q = line
            current_a = ''
        elif line.startswith('A1') or line.startswith('A2') or line.startswith('Answer'):
           
            current_a += line[2:] + '\n'
  
    if current_q:
        pairs.append((current_q, current_a))
    return pairs

# %%
# Create a temporary DataFrame to store the cleaned data
columns = ['Title', 'DOI', 'Authors', 'Full_Text_URL', 'Question', 'Answer']
cleaned_data = pd.DataFrame(columns=columns)

for id, row in temp_df[:1].iterrows():
    paragraphs = get_paragraphs(row['Full_Text_Content'])
    for para in paragraphs:
        qna = []
        response = get_response(para)
        qna.append(response)

        # Create a temporary file
        with tempfile.NamedTemporaryFile(mode='w', delete=False) as temp_file:
            for qa in qna:
                print(qa)
                temp_file.write(qa)
            temp_file.flush()
            temp_file_path = temp_file.name

        with open(temp_file_path, 'r') as temp_file:
            lines = temp_file.readlines()
            pairs = parse_qa_pairs(lines)
        
        new_rows = []
        for Q, A in pairs:
            if Q.startswith('Q1') or Q.startswith('Q2') or Q.startswith('Question 1') or Q.startswith('Question 2'):
                new_rows.append({'Title': row['Title'], 'DOI': row['DOI'], 'Authors': row['Authors'], 'Full_Text_URL': row['Full_Text_URL'], 'Question': Q, 'Answer': A.strip()})
            elif Q.startswith('A1') or Q.startswith('A2') or Q.startswith('Answer'):
                new_rows.append({'Title': row['Title'], 'DOI': row['DOI'], 'Authors': row['Authors'], 'Full_Text_URL': row['Full_Text_URL'], 'Question': A.strip(), 'Answer': Q})
        
        cleaned_data = pd.concat([cleaned_data, pd.DataFrame(new_rows)], ignore_index=True)

# Clean the data in the DataFrame
cleaned_data['Question'] = cleaned_data['Question'].str.replace(r'^[Question\d\.\:\- ]*', '', regex=True)
cleaned_data['Answer'] = cleaned_data['Answer'].str.replace(r'^[Answer\d\.\:\- ]*', '', regex=True)

# Write the cleaned data to the output CSV file
cleaned_data.to_csv('output_clean.csv', index=False)
# Out:
#  What is the Diagnostic Related Group (DRG) system?
# Answer: The Diagnostic Related Group (DRG) system is a system that classifies hospital cases into identifiable groups in order to identify ‘products’ that a hospital provides. This model of classification is based on the International Classification of Diseases (ICD) and the presence of complications or co-morbidity.
#
# 4. What countries has the DRG system spread to?
# Answer: The DRG system has spread to countries such as Australia, Denmark, France, Germany, Austria, the Netherlands and Russia; followed by a less rapid spread from acute care into long-term care and psychiatry.
#
#
# Q1: What was the main aim of PbR?
# A1: The main aim of PbR was to improve efficiency and increase value for money in the NHS by enhancing service quality, facilitating patient choice, enabling service innovation, improving quality of service and reducing waiting times by rewarding healthcare providers for the volumes of work completed.
#
# Q2: When did the first NHS foundation trust move to the full PbR system?
# A2: The first NHS foundation trust applicants moved to the full PbR system in 2005–06.
#
#
# Q1. What does HRG stand for?
# A1. HRG stands for healthcare resource group.
#
# Q2. How often are HRGs reviewed?
# A2. HRGs are reviewed every four years to ensure accuracy.
#
# Q3. What is the aim of the payment by results scheme?
# A3. The aim of the payment by results scheme is to allow the commissioning of activity volumes, from a plurality of providers, on the basis of a standard, national pricing tariff.
#
# Q4. What was the overarching aim of the CQUIN framework?
# A4. The overarching aim of the CQUIN framework was to promote non-price competition, such as provider differentiation on the basis of service quality.
#
#
# Q1: What was the purpose of CQUIN payment framework?
# A1: The purpose of the Commissioning for Quality and Innovation (CQUIN) payment framework was to help local commissioners identify and agree quality improvement schemes and enable them to reward excellence by linking a proportion of healthcare providers’ income to the achievement of local quality improvement goals.
#
# Q2: Why was CQUIN focused on VTE?
# A2: CQUIN was focused on VTE because there are large gaps in the provision of this key patient safety intervention, despite evidence-based guidelines recommending routine use of thromboprophylaxis for most hospitalised patients over 23 years prior.
# Q1: What is the name of the framework introduced to provide financial incentive to hospitals for focusing on VTE prevention?
# A1: The Commissioning for Quality and Innovation (CQUIN) framework was introduced to provide financial incentive for hospitals to focus on VTE prevention.
#
# Q2: How many hospitalised patients die from preventable VTE each year?
# A2: The House of Commons Health Select Committee estimated that over 25,000 patients admitted to hospital die each year from preventable VTE.
#
#
# Q: What is the CQUIN payment framework?
# A: The CQUIN Payment Framework is an English healthcare system that links a proportion of providers’ income to the achievement of local quality improvement goals.
#
# Q: How does the CQUIN Payment Framework incentivize providers?
# A: The CQUIN Payment Framework incentivizes providers through rewards such as bonuses for meeting specific targets, as well as withholding a percentage of contract value for failure to report according to contractual obligations.
#
#
# Q1. What is the estimated value of the CQUIN scheme for PCTs?
# A1. The financial value of a CQUIN scheme is specified nationally as a % of actual outturn value of the provider's contract. At the start of the year, the expected value of the scheme should be calculated as a % of the estimated total outturn contract value for commissioned patient services.
#
# Q2. What motivates individuals working for PCTs to successfully implement local quality improvement goals when they have no personal benefit in terms of monetary reward?
# A2. Different types of motivation, such as intrinsic motivation, altruism, recognition, and professional pride, may act as either a barrier or facilitator to the successful implementation of the payment by results schemes in the wider NHS.
#
#
# Q1. What does the ninth annual survey suggest about NHS staff?
# A1. The ninth annual survey indicates that 90% of NHS staff feel that their role makes a difference to patients and 87% are satisfied with the quality of care they personally give.
#
# Q2. What were the revised NICE guidance in January 2010?
# A2. The revised NICE guidance in January 2010 formalised differing hospital guidelines for attributing VTE risk, administering appropriate prophylaxis and dealing with contraindications. This meant that compliance against a national target was now able to be monitored for every acute provider.
#
#
# Question 1: What is the first variable that determines an employee's motivation to perform effectively?
# Answer: The first variable that determines an employee's motivation to perform effectively is the effort-reward probability.
#
# Question 2: How does the CQUIN framework work to bridge the gap between individual and organisational reward?
# Answer: The CQUIN framework works to bridge the gap between individual and organisational reward by creating and rewarding a culture of continuous quality improvement with stretching goals and measured outcomes agreed in contracts with PCTs on an annual basis.
#
#
# Q1. What are P45 targets?
# A1. P45 targets are public service targets in health which have commonly become known as "P45" targets. If certain targets are not achieved, the job may be at risk.
#
# Q2. What factors are included in the total reward package for trust chief executives?
# A2. The total reward package for Trust chief executives commonly includes basic pay, a spot rate salary determined by the role and an organisational weighting factor alongside an annual performance bonus scheme.
#
#
# Q1. What role does concern for welfare and treatment of patients have in driving up healthcare delivery standards?
# A1. Concern for the welfare and treatment of patients has always been an over-riding factor in driving up standards in healthcare delivery.
#
# Q2. How did the NHS Staff Survey data indicate that staff felt about their role and quality of patient care?
# A2. The NHS staff survey data for 2011 indicated that nine out of ten staff felt that their role made a difference to patients, with 69% saying they were able to deliver the quality of patient care to which they aspired.
#
# Q3. What is the purpose of CQUIN rewards for providers?
# A3. CQUIN rewards are made available to providers through contracts with PCTs for the purpose of encouraging providers to deliver higher standards of care.
#
#
# Q1: How can healthcare professionals be incentivised to adopt new working practices?
# A1: Healthcare professionals may be incentivised to adopt revised working practices in order to 'earn' extra monies at a departmental level in order to both improve their working practices and increase patient satisfaction.
#
# Q2: What is the purpose of increased surveillance of clinical practice?
# A2: Increased surveillance of clinical practice allows for ongoing intra-organisational surveillance through mandatory audit activity, and inter-organisational, public comparison of how well different hospitals risk assess and treat VTE also becomes possible.
#
#
# Q1: What conditions did the paper examine to facilitate the implementation of revised VTE guidance in 2010?
# A1: The paper examined the organisational and workplace conditions that favour the implementation of national revised VTE guidance in 2010 in four hospitals in the greater South West of England, as well as the attitudes of staff towards changes to VTE risk assessment policies upon which CQUIN targets were based.
#
# Q2: How did the review use longitudinal case studies to assess the hospitals’ VTE prevention activities?
# A2: The review used 816 randomly selected longitudinal case studies of the hospitals’ VTE prevention activities, complemented by a qualitative study into the practical responses by healthcare professionals to the revised national guidance and the imposition of payment by results (PbR).
#
#
# 1. How was the implementation of evidence-based national guidance on VTE prevention across general medicine and orthopaedics in four hospital study sites compared?
# Answer: A multi-method approach was adopted in order to compare the differences in the implementation of evidence-based national guidance on VTE prevention across general medicine and orthopaedics in four hospital study sites.
#
# 2. What financial incentives were in place for acute providers through the CQUIN payment framework?
# Answer: The financial incentives in place for acute providers through the CQUIN payment framework included potential public exposure of how well a hospital does in terms of meeting CQUIN targets for VTE risk assessment and prevention.
#
#
# Descriptive Question 1: What four hospitals were selected as study sites?
# Answer 1: The four hospitals selected as study sites were Hospital A, Hospital B, Hospital C, and Hospital D.
#
# Descriptive Question 2: What motivated the decision to compare patients within General Medicine and Orthopaedics?
# Answer 2: The decision to compare patients within General Medicine and Orthopaedics was motivated by the hypothesis that a speciality with a relatively high proportion of planned admissions (orthopaedics) would find it easier to implement the revised guidance than a speciality with a relatively high proportion of unplanned admissions (general medicine).
#
#
# Q1: How did the researchers minimize the effects of the seasonal tourist influx and doctor rotation for their sample?
# A1: The researchers drew their sample from a list of all adult admissions for stays over 24 hours for the same three-week period in October 2009 and 2010 in order to minimize the effects of both the seasonal influx of tourists and the rotation of junior doctors.
#
# Q2: What staff were identified for key decisions about VTE prevention and treatment during a hospital episode?
# A2: The staff identified for key decisions about VTE prevention and treatment during a hospital episode included junior medical staff, VTE nurses, orthopaedic nurses, pre-operative assessment staff, pharmacists and senior hospital managers.
#
#
# Q1: How many patient files were used to conduct the audit?
# A1: A sample of 408 patient files across all four hospitals were used to conduct the audit.
#
# Q2: How did the statistical analysis help to prove that the admission data was not ‘cherry-picked’?
# A2: The statistical analysis helped to confirm that in those hospitals where the audit team was unable to take its own sample, a random cross section of files appeared to have been made available without having been manipulated by the hospital records departments.
#
#
# Q1: How many medical records were sampled in 2009?
# A1: 816 medical records were sampled in 2009.
#
# Q2: How many interviews were conducted over the 18 month period?
# A2: Forty four interviews were conducted over the 18 month period.
#
#
# Q1: What are the characteristics of hospitals that are awarded exemplar status?
# A1: Hospitals that are awarded exemplar status must demonstrate quality and good practice in VTE care, provide examples of good practice, educational and audit material, and provide advice on VTE care.
#
# Q2: What is needed for a hospital to receive exemplar status?
# A2: Hospitals must demonstrate quality and good practice in VTE care, provide examples of good practice, educational and audit material, and provide advice on VTE care in order to be awarded the exemplar status.
#
#
# Q1: How many beds are present in Hospital A?
# A1: Hospital A has over 900 beds.
#
# Q2: How many staff are employed in Hospital B?
# A2: Hospital B employs approximately 5200 staff.
#
#
# Q1: What is the recent opening of Hospital C?
# A1: The recent opening of Hospital C is a new medical teaching facility which has further enhanced its strong reputation for education and training.
#
# Q2: What is Foundation Trust status?
# A2: Foundation Trust status is a type of public sector organisation providing NHS services which is independent from the Department of Health and is accountable to local communities.
#
# Q1. What measures have been taken to improve VTE prevention?
# A1. Measures taken to improve VTE prevention include an increase in the recording of VTE risk assessment and prescribing of appropriate thrombo-prophylaxis, as well as the availability of CQUIN monies for each hospital if local quality improvement goals were met.
#
# Q2. What ethical considerations were taken into account for this study?
# A2. Ethical approval was not necessary for this study due to its service evaluation and audit nature. However, honorary contracts for the two researchers were required in three of the four hospitals, and a letter of access was necessary for the fourth. Additionally, researcher safety was ensured by requiring knowledge of the date, time and place of interviews.
#
#
# Q1: What was the biggest overall percentage change in risk assessment in 2009?
# A1: The biggest overall percentage change in risk assessment in 2009 was in Hospital A with an increase from 43.1% to 90.2%.
#
# Q2: What were the Department of Health VTE exemplar site status awarded to Hospital A in December 2008?
# A2: Hospital A was awarded Department of Health VTE exemplar site status due to its policy of prescribing universal pharmaceutical prophylaxis unless contra-indicated.
#
#
# Q1. What percentage of patients were risk assessed for VTE in 2009?
# A1. 43.1%.
#
# Q2. What was the improvement in risk assessment from 2009 to 2010?
# A2. Auditable risk assessments rose from 43.1% in 2009 to 90.2% in 2010.
#
#
# Q1: What was the overarching aim to prevent VTE during a hospital episode?
# A1: The overarching aim to prevent VTE during a hospital episode was based on the cumulative risk factors of assessment and treatment.
#
# Q2: How did the differentiated risk assessments of Hospital D vary across specialisms?
# A2: The differentiated risk assessments of Hospital D varied in terms of the end output of the algorithm, but the input remained consistent throughout the hospital.

# %%
df = pd.read_csv('output_clean.csv')
df.sample(1)
# Out:
#                                                Title  \
# 5  Has incentive payment improved venous thrombo-...
#
#                               DOI  \
# 5  10.12688/f1000research.2-41.v1
#
#                                              Authors  \
# 5  [{'Child', 'Sue'}, {'Sheaff', 'Rod'}, {'Boiko'...
#
#                                        Full_Text_URL  \
# 5  https://f1000research.com/extapi/article/xml?d...
#
#                         Question  \
# 5  Why was CQUIN focused on VTE?
#
#                                               Answer
# 5  CQUIN was focused on VTE because there are lar...
